# %%
# %pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached branca-0.8.2-py3-none-any.whl.metadata (1.7 kB)
# ...
# Using cached folium-0.20.0-py2.py3-none-any.whl (113 kB)
# Using cached branca-0.8.2-py3-none-any.whl (26 kB)
# ...
#
#    ---------------------------------------- 0/2 [branca]
#    -------------------- ------------------- 1/2 [folium]
#
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Mati\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python313\\site-packages\\folium\\raster_layers.py'
# Check the permissions.
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# %pip install pandas
# %pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.8 MB 515.0 kB/s eta 0:00:18
#    -- ------------------------------------- 0.5/9.8 MB 515.0 kB/s eta 0:00:18
#    -- ------------------------------------- 0.5/9.8 MB 515.0 kB/s eta 0:00:18
#    --- ------------------------------------ 0.8/9.8 MB 555.6 kB/s eta 0:00:17
#    --- ------------------------------------ 0.8/9.8 MB 555.6 kB/s eta 0:00:17
#    ---- ----------------------------------- 1.0/9.8 MB 571.1 kB/s eta 0:00:16
# ...

# %%
import pandas as pd
import numpy as np
import folium

# %%
# %pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
dataframe1 = pd.read_excel("D:/python-ds/Visualization-using-folium-main/cities-covid-19.xlsx", sheet_name="Sheet1")

# %%
dataframe2 = pd.read_excel("D:/python-ds/Visualization-using-folium-main/coordinates-pk.xlsx", sheet_name="Sheet1")

# %%
#now we clean the data in it
dataframe1.fillna(0)
#we shall remove the unnamed columns from the dataset
missing_data = pd.isna(dataframe1.columns).sum()
print("Missing data of 1st file:"+str(missing_data))

dataframe2.fillna(0)
#we shall remove the unnamed columns from the dataset
missing_data2 = pd.isna(dataframe2.columns).sum()
print("Missing data of 2nd file:"+str(missing_data2))
# Out:
# Missing data of 1st file:0
# Missing data of 2nd file:0

# %%
dataframe=pd.merge(dataframe1,dataframe2)

# %%
#loading the map of pakistan
Pakistan=folium.Map(location=[30.375321,69.345116],zoom_start=5.2)

# %%
Pakistan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
#now we shall add all the data on map of Pakistan
for cities,latitude,longitude,cases,Population in zip(list(dataframe['Cities']),list(dataframe
['Latitude']),list(dataframe['Longitude']),list(dataframe['Number-of-confirmed-cases']),list(dataframe['Population'])):
    folium.CircleMarker(location=[latitude,longitude],
                       radius=6,
                       color='green',
                       fill= True,
                       fill_color='green').add_to(Pakistan)
    
    #now for displaying
    folium.Marker(location=[latitude,longitude],
                  popup=folium.Popup(('<strong><b>Cities : '+cities+'</strong> <br>' +
                  '<strong><b>Latitude : '+str(latitude)+'</strong> <br>' +
                  '<strong><b>Longitude: '+str(longitude)+'</strong> <br>' +
                  '<strong><b>Number-of-confirmed-cases : '+str(cases)+'</strong> <br>' +
                  '<strong><b>Population : '+str(Population)+'</strong>'),max_width=200)).add_to(Pakistan)
