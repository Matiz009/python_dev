# %%
marks = [85, 92, 78, 90]

# %%
print("Marks:", marks)
# Out:
# Marks: [85, 92, 78, 90]

# %%
cart = []
cart.append("iPhone 15")      # user adds a phone
cart.append("AirPods")        # then earbuds
cart.append("AirPods")        # gifts one to a friend - duplicate is fine
cart.remove("iPhone 15")      # changed their mind
print(cart)                   # ['AirPods', 'AirPods']
# Out:
# ['AirPods', 'AirPods']

# %%
nums = [10, 20, 30]

# --- ADDING ---
nums.append(40)          # add ONE item at the end        -> [10, 20, 30, 40]
nums.insert(1, 15)       # add at a specific index        -> [10, 15, 20, 30, 40]
nums.extend([50, 60])    # add MANY items at the end      -> [10, 15, 20, 30, 40, 50, 60]

# --- REMOVING ---
nums.remove(15)          # remove by VALUE (first match)
last = nums.pop()        # remove & RETURN the last item  -> last = 60
first = nums.pop(0)      # remove & RETURN by index       -> first = 10
# nums.clear()           # empty the whole list

# --- SEARCHING ---
nums.index(30)           # position of a value            -> 1
nums.count(20)           # how many times it appears      -> 1
30 in nums               # membership check               -> True

# --- ORDERING ---
nums.sort()              # sort IN PLACE (changes nums)
nums.sort(reverse=True)  # descending
nums.reverse()           # flip the order
sorted_copy = sorted(nums)   # returns a NEW sorted list, original untouched

# --- SIZE & SLICING ---
len(nums)                # how many items
nums[0]                  # first item
nums[-1]                 # last item
nums[1:3]                # slice: index 1 up to (not including) 3
nums[::-1]               # a REVERSED COPY (slicing trick)
# Out:
# [50, 40, 30, 20]

# %%
print("Class Started")
# Out:
# Class Started

# %%
students = ["Alice", "Bob", "Charlie", "David"]

# %%
students
# Out:
# ['Alice', 'Bob', 'Charlie', 'David']

# %%
print(students[0])
# Out:
# Alice

# %%
for student in students:
    print(student)
# Out:
# Alice
# Bob
# Charlie
# David

# %%
numbers = [1, 2, 3, 4, 5]

# %%
for number in numbers:
    number=number +2
    print(number)
# Out:
# 3
# 4
# 5
# 6
# 7

# %%
numbers.remove(3)  # removes the first occurrence of 3

# %%
numbers
# Out:
# [1, 2, 4, 5]

# %%
numbers.pop()
# Out:
# 5

# %%
numbers
# Out:
# [1, 2, 4]

# %%
numbers.pop()
# Out:
# 4

# %%
numbers
# Out:
# [1, 2]

# %%
2 in numbers
# Out:
# True

# %%
'Bob' in students
# Out:
# True

# %%
unsorted_numbers = [5, 2, 9, 1, 5, 6]

# %%
unsorted_numbers.sort()

# %%
unsorted_numbers
# Out:
# [1, 2, 5, 5, 6, 9]

# %%
unsorted_numbers1 = [5, 2, 9, 1, 5, 6]

# %%
unsorted_numbers1
# Out:
# [5, 2, 9, 1, 5, 6]

# %%
sorted_numbers = sorted(unsorted_numbers1)

# %%
sorted_numbers
# Out:
# [1, 2, 5, 5, 6, 9]

# %%
unsorted_numbers1
# Out:
# [5, 2, 9, 1, 5, 6]

# %%
list2  = [5, 2, 9, 1, 5, 6]

list2.sort()

list2
# Out:
# [1, 2, 5, 5, 6, 9]

# %%
list3= [5, 2, 9, 1, 5, 6]

list4=sorted(list3)

list3
list4
# Out:
# [1, 2, 5, 5, 6, 9]

# %%
list3
# Out:
# [5, 2, 9, 1, 5, 6]

# %%
students=["Alice","Charlie", "David", "Bob","Ahmed"]

# %%
students.sort()

# %%
students
# Out:
# ['Ahmed', 'Alice', 'Bob', 'Charlie', 'David']

# %%
staff=["A","C", "D", "B","A"]

# %%
staff
# Out:
# ['A', 'C', 'D', 'B', 'A']

# %%
staff_sorted=sorted(staff)

# %%
staff_sorted
# Out:
# ['A', 'A', 'B', 'C', 'D']

# %%
staff
# Out:
# ['A', 'C', 'D', 'B', 'A']

# %%
list_Numbers=[5, 2, 9, 1, 5, 6]

# %%
def square(x):
    return x**2

# %%
squared_list=map(square, list_Numbers)

# %%
# Out:
# 25
# 4
# 81
# 1
# 25
# 36

# %%
def square(x):
    return x**2

# %%
print(square(12))
# Out:
# 144

# %%
print(square(11))
# Out:
# 121

# %%
list_numbers_to_square=[5, 2, 9, 1, 5, 6]

# %%
print(list_numbers_to_square)
# Out:
# [5, 2, 9, 1, 5, 6]

# %%
for i in list_numbers_to_square:
    print(i)
# Out:
# 5
# 2
# 9
# 1
# 5
# 6

# %%
def addTwotoNumbers(x):
    return x+2

# %%
print(addTwotoNumbers(8))
# Out:
# 10

# %%
newList2=map(addTwotoNumbers, list_numbers_to_square)

# %%
for number in newList2:
    print(number)
# Out:
# 7
# 4
# 11
# 3
# 7
# 8
