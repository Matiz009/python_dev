# %%
fruits = ['Apple']

# %%
fruits
# Out:
# ['Apple']

# %%
fruits[0]
# Out:
# 'Apple'

# %%
fruits.append('Mango')

# %%
fruits
# Out:
# ['Apple', 'Mango']

# %%
fruits.insert(0,'Banana')

# %%
fruits
# Out:
# ['Banana', 'Apple', 'Mango']

# %%
fruits.remove('Mango')

# %%
fruits
# Out:
# ['Banana', 'Apple']

# %%
fruits.extend([50, 60])

# %%
fruits
# Out:
# ['Banana', 'Apple', 50, 60]

# %%
fruits.append(True)

# %%
fruits
# Out:
# ['Banana', 'Apple', 50, 60, True]

# %%
fruits.pop()
# Out:
# True

# %%
fruits
# Out:
# ['Banana', 'Apple', 50, 60]

# %%
fruits.pop()
# Out:
# 60

# %%
fruits.pop()
# Out:
# 50

# %%
nums=[1,3,5,6,7,8,9,5,2]

# %%
b=sorted(nums)

# %%
b
# Out:
# [1, 2, 3, 5, 5, 6, 7, 8, 9]

# %%
nums
# Out:
# [1, 3, 5, 6, 7, 8, 9, 5, 2]

# %%
nums.sort()

# %%
nums
# Out:
# [1, 2, 3, 5, 5, 6, 7, 8, 9]

# %%
def checkEven(x):
    return x % 2 == 0

# %%
list(map(checkEven, nums))
# Out:
# [False, True, False, False, False, True, False, True, False]

# %%
for num in nums:
    print(checkEven(num))
# Out:
# False
# True
# False
# False
# False
# True
# False
# True
# False
