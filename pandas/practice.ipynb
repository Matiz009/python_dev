# %% [markdown]
# # Pandas Practise

# %%
students=['ali','hamza','jamal']

# %%
students
# Out:
# ['ali', 'hamza', 'jamal']

# %%
! pip install pandas

# %%
import pandas as pd

# %%
recipes = pd.Series(
    ['biryani','qorma','pizza'],
    index=['Ali','Ahmed','Rizwan'],
    name='recipes'
)

# %%
recipes
# Out:
# Ali       biryani
# Ahmed       qorma
# Rizwan      pizza
# Name: recipes, dtype: object

# %%
data_frame=pd.DataFrame({
    'names':['ali','ahmed','bilal'],
    'marks':[89,90,67],
    'grade':['B','A','C']
})

# %%
print(data_frame)
# Out:
#    names  marks grade
# 0    ali     89     B
# 1  ahmed     90     A
# 2  bilal     67     C

# %%
print(data_frame['marks'].mean())
# Out:
# 82.0

# %%
print(data_frame['marks'].max())
# Out:
# 90

# %%
print(data_frame['marks'].count())
# Out:
# 3

# %%
print(data_frame['marks'].value_counts())
# Out:
# marks
# 89    1
# 90    1
# 67    1
# Name: count, dtype: int64

# %%
diseases=pd.read_csv('./heart-disease.csv')

# %%
diseases
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
print(diseases.head())
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
pd.read_excel('./tes.xlsx',sheet_name="Grades")
# Out:
#    Unnamed: 0             Unnamed: 1                   Unnamed: 2 Unnamed: 3  \
# 0         NaN  Grades for Evaluation                          NaN        NaN
# 1         NaN                    NaN                          NaN        NaN
# 2         NaN                  GRADE                          NaN        NaN
# 3         NaN                      5             Outstanding (OS)          A
# 4         NaN                      4  Exceeding Expectations (EE)          B
# 5         NaN                      3    Meeting Expectations (ME)          C
# 6         NaN                      2      Below Expectations (BE)          D
# 7         NaN                      1        Serious Deficiencies           E
#
#                                           Unnamed: 4 Schedule - "B"
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2                                        EXPLANATION          Score
# ...

# %%
data_frame.to_csv("marks.csv", index=True)
