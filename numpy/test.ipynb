# %%
import numpy as np

# 1D array from a Python list
scores = np.array([88, 92, 75, 61, 95])

# 2D array — student × subject score matrix
gradebook = np.array([
    [88, 75, 91],   # Ali:   Math, Sci, Eng
    [92, 89, 85],   # Sara:  Math, Sci, Eng
    [79, 91, 72],   # Bilal: Math, Sci, Eng
])

print(scores.dtype)        # int64
print(gradebook.shape)     # (3, 3)
print(gradebook.ndim)      # 2
