# %% [markdown]
# # Task 3 — Lahore City Explorer (pandas + Folium)
#
# **Solution notebook.** Every code cell is commented to explain the *why* behind each step.
#
# File used: `lahore_places.csv`
#
# > Note: the final map object is displayed inline (Folium maps render directly
# > in a Jupyter cell), and is also saved to `lahore_map.html` so it can be
# > opened outside the notebook too.

# %%
# Imports
import pandas as pd
import folium

# %% [markdown]
# ## Part A — Load & Explore

# %%
from folium.plugins import HeatMap
df = pd.read_csv("lahore_places.csv")
print(df.shape)
df.head()
# Out:
# (20, 6)
#                 name  category      lat      lon  avg_rating  daily_footfall
# 0    Badshahi Mosque  Heritage  31.5881  74.3103         4.8            9500
# 1        Lahore Fort  Heritage  31.5882  74.3150         4.7            7200
# 2  Wazir Khan Mosque  Heritage  31.5828  74.3323         4.6            4100
# 3   Shalimar Gardens  Heritage  31.5952  74.3811         4.5            3800
# 4   Minar-e-Pakistan  Heritage  31.5925  74.3095         4.6            6100

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            20 non-null     str
#  1   category        20 non-null     str
#  2   lat             20 non-null     float64
#  3   lon             20 non-null     float64
#  4   avg_rating      20 non-null     float64
#  5   daily_footfall  20 non-null     int64
# dtypes: float64(3), int64(1), str(2)
# memory usage: 1.1 KB

# %%
# Average rating and TOTAL footfall per category
# (mean makes sense for rating; sum makes sense for footfall — we want total traffic, not average)
category_summary = df.groupby("category").agg(
    avg_rating=("avg_rating", "mean"),
    total_footfall=("daily_footfall", "sum"),
).sort_values("total_footfall", ascending=False)

category_summary
# Out:
#             avg_rating  total_footfall
# category
# Shopping      4.183333           51300
# Heritage      4.650000           41700
# Education     4.200000           15000
# Park          4.175000           13000
# Recreation    4.000000            4700
# Sports        4.500000            2600
# Museum        4.400000            1800

# %%
# Single busiest place overall
busiest = df.sort_values("daily_footfall", ascending=False).iloc[0]
print(f"Busiest place: {busiest['name']} ({busiest['category']}) "
      f"with {busiest['daily_footfall']:,} daily visitors")

df.sort_values("daily_footfall", ascending=False).head()
# Out:
# Busiest place: Punjab University (New Campus) (Education) with 15,000 daily visitors
#                               name   category      lat      lon  avg_rating  \
# 18  Punjab University (New Campus)  Education  31.4998  74.2953         4.2
# 8                    Emporium Mall   Shopping  31.4802  74.3439         4.3
# 16                     Data Darbar   Heritage  31.5852  74.3184         4.7
# 9                    Packages Mall   Shopping  31.4746  74.3625         4.4
# 7                  Anarkali Bazaar   Shopping  31.5686  74.3103         4.1
#
#     daily_footfall
# 18           15000
# 8            12500
# 16           11000
# 9            10200
# 7             9900

# %% [markdown]
# ## Part B — Base Map

# %%
# Center roughly on Lahore, with a zoom level that shows the whole city
m = folium.Map(location=[31.53, 74.34], zoom_start=12, tiles="OpenStreetMap")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_240476505264de572007d7cadc6a48b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_240476505264de572007d7cadc6a48b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_240476505264de572007d7cadc6a48b4 = L.map(
#                 &quot;map_240476505264de572007d7cadc6a48b4&quot;,
#                 {
#                     center: [31.53, 74.34],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2141f29920cabb7cf0643c6f6eeebb13 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2141f29920cabb7cf0643c6f6eeebb13.addTo(map_240476505264de572007d7cadc6a48b4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Part C — Color-Code by Category

# %%
# Check exactly which categories exist before assigning colors —
# don't guess, read it off the real data.
print(sorted(df["category"].unique()))
# Out:
# ['Education', 'Heritage', 'Museum', 'Park', 'Recreation', 'Shopping', 'Sports']

# %%
# One distinct color per category
category_colors = {
    "Heritage": "darkred",
    "Museum": "purple",
    "Shopping": "blue",
    "Sports": "orange",
    "Park": "green",
    "Recreation": "cadetblue",
    "Education": "gray",
}

# Fallback color for any category not explicitly listed above
DEFAULT_COLOR = "black"

# %% [markdown]
# ## Part D — Size by Footfall + Part F — Toggleable Layers (built together)

# %%
# Rebuild the map fresh so we don't stack duplicate layers if this cell re-runs.
m = folium.Map(location=[31.53, 74.34], zoom_start=12, tiles="OpenStreetMap")

# One FeatureGroup per category so students can toggle categories on/off later.
feature_groups = {
    category: folium.FeatureGroup(name=category)
    for category in df["category"].unique()
}

for row in df.itertuples(index=False):
    color = category_colors.get(row.category, DEFAULT_COLOR)

    # Radius scaled by footfall: divisor chosen so circles stay readable
    # (not tiny dots, not overlapping blobs) for this dataset's value range.
    radius = row.daily_footfall / 1500

    marker = folium.CircleMarker(
        location=[row.lat, row.lon],
        radius=radius,
        popup=folium.Popup(
            f"<b>{row.name}</b><br>"
            f"Category: {row.category}<br>"
            f"Rating: {row.avg_rating}★<br>"
            f"Daily footfall: {row.daily_footfall:,}",
            max_width=250,
        ),
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.6,
    )
    marker.add_to(feature_groups[row.category])

# Add every category's FeatureGroup to the map
for group in feature_groups.values():
    group.add_to(m)

# %% [markdown]
# ## Part E — Heatmap Layer

# %%
# Weighted heatmap using footfall as the weight, so it visualizes DENSITY
# separately from the individual colored markers above.
heat_data = df[["lat", "lon", "daily_footfall"]].values.tolist()
HeatMap(heat_data, name="Footfall Heatmap", radius=25, blur=15).add_to(m)

# %%
# Layer control lets a viewer toggle each category (and the heatmap) on/off
folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60e0426919e8c54fb26406f7efd8d201 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60e0426919e8c54fb26406f7efd8d201&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60e0426919e8c54fb26406f7efd8d201 = L.map(
#                 &quot;map_60e0426919e8c54fb26406f7efd8d201&quot;,
#                 {
#                     center: [31.53, 74.34],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a806eaa16a0c2b495441c7ac66f8ad28 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a806eaa16a0c2b495441c7ac66f8ad28.addTo(map_60e0426919e8c54fb26406f7efd8d201);
#
#
#             var feature_group_e46dac48d791f071ba763c25384ee667 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_0e66d26ed539e1da9065b9acc0521b9f = L.circleMarker(
#                 [31.5881, 74.3103],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6.333333333333333, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_e46dac48d791f071ba763c25384ee667);
#
#
#         var popup_77621cc88b3150ceb6b59ece078bcdfe = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_fba67505e39bb5c7324c7cd0fa8147fe = $(`&lt;div id=&quot;html_fba67505e39bb5c7324c7cd0fa8147fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Badshahi Mosque&lt;/b&gt;&lt;br&gt;Category: Heritage&lt;br&gt;Rating: 4.8★&lt;br&gt;Daily footfall: 9,500&lt;/div&gt;`)[0];
#                 popup_77621cc88b3150ceb6b59ece078bcdfe.setContent(html_fba67505e39bb5c7324c7cd0fa8147fe);
#
#
#
#         circle_marker_0e66d26ed539e1da9065b9acc0521b9f.bindPopup(popup_77621cc88b3150ceb6b59ece078bcdfe)
#         ;
#
#
#
#
#             var circle_marker_4fdc5e5d12865e460d96a534b061aa49 = L.circleMarker(
#                 [31.5882, 74.315],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_e46dac48d791f071ba763c25384ee667);
#
#
#         var popup_6ee57c4e50c7dc12f405f1599a4e95d5 = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_a1c97d00f5f4076bc2ded5934b041334 = $(`&lt;div id=&quot;html_a1c97d00f5f4076bc2ded5934b041334&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Lahore Fort&lt;/b&gt;&lt;br&gt;Category: Heritage&lt;br&gt;Rating: 4.7★&lt;br&gt;Daily footfall: 7,200&lt;/div&gt;`)[0];
#                 popup_6ee57c4e50c7dc12f405f1599a4e95d5.setContent(html_a1c97d00f5f4076bc2ded5934b041334);
#
#
#
#         circle_marker_4fdc5e5d12865e460d96a534b061aa49.bindPopup(popup_6ee57c4e50c7dc12f405f1599a4e95d5)
#         ;
#
#
#
#
#             var circle_marker_8583aee5cdf20267a45c6955251cbe54 = L.circleMarker(
#                 [31.5828, 74.3323],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2.7333333333333334, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_e46dac48d791f071ba763c25384ee667);
#
#
#         var popup_9a3f12fe0f7e506ac44525c708febc8c = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_83c8c5040845908dba615f7

# %% [markdown]
# ## Part G — Save

# %%
m.save("lahore_map.html")
print("Saved lahore_map.html — open it in a browser to explore the interactive map.")
# Out:
# Saved lahore_map.html — open it in a browser to explore the interactive map.

# %% [markdown]
# ## Bonus Challenge
#
# - A walking route between nearby heritage sites, with straight-line distances printed
# - A "must-visit only" filtered map (rating >= 4.5)

# %%
from math import radians, sin, cos, sqrt, atan2

def haversine_km(lat1, lon1, lat2, lon2):
    """Straight-line distance between two lat/lon points, in kilometers.
    This is a simplification (no real roads/routing) — just enough to
    illustrate the idea, matching a Dijkstra-style routing project's spirit.
    """
    R = 6371  # Earth's radius in km
    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)
    a = sin(dlat / 2) ** 2 + cos(radians(lat1)) * cos(radians(lat2)) * sin(dlon / 2) ** 2
    return R * 2 * atan2(sqrt(a), sqrt(1 - a))


route_names = ["Badshahi Mosque", "Lahore Fort", "Data Darbar"]
route_df = df[df["name"].isin(route_names)].set_index("name").loc[route_names]

route_map = folium.Map(location=[31.585, 74.315], zoom_start=14)
coords = list(zip(route_df["lat"], route_df["lon"]))

for name, (lat, lon) in zip(route_names, coords):
    folium.Marker([lat, lon], popup=name, icon=folium.Icon(color="darkred")).add_to(route_map)

folium.PolyLine(coords, color="blue", weight=4, opacity=0.8).add_to(route_map)

# Print distance between each consecutive stop
print("Route distances:")
for i in range(len(coords) - 1):
    d = haversine_km(*coords[i], *coords[i + 1])
    print(f"  {route_names[i]} -> {route_names[i+1]}: {d:.2f} km")

route_map
# Out:
# Route distances:
#   Badshahi Mosque -> Lahore Fort: 0.45 km
#   Lahore Fort -> Data Darbar: 0.46 km
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56188b68cba0caf28915cced3380477c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56188b68cba0caf28915cced3380477c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56188b68cba0caf28915cced3380477c = L.map(
#                 &quot;map_56188b68cba0caf28915cced3380477c&quot;,
#                 {
#                     center: [31.585, 74.315],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4fa47895dbe1f7082e4e62db3947ea70 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4fa47895dbe1f7082e4e62db3947ea70.addTo(map_56188b68cba0caf28915cced3380477c);
#
#
#             var marker_ee936d62be4a5aab7093b1a2db86fa6a = L.marker(
#                 [31.5881, 74.3103],
#                 {
# }
#             ).addTo(map_56188b68cba0caf28915cced3380477c);
#
#
#             var icon_3289ae3292a8ccc55cabc3417efa30d4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkred&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e9ebf71427684bdf1047614fc6d96dde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd169bbb253b95b9750fbecbbdaf1f06 = $(`&lt;div id=&quot;html_cd169bbb253b95b9750fbecbbdaf1f06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Badshahi Mosque&lt;/div&gt;`)[0];
#                 popup_e9ebf71427684bdf1047614fc6d96dde.setContent(html_cd169bbb253b95b9750fbecbbdaf1f06);
#
#
#
#         marker_ee936d62be4a5aab7093b1a2db86fa6a.bindPopup(popup_e9ebf71427684bdf1047614fc6d96dde)
#         ;
#
#
#
#
#                 marker_ee936d62be4a5aab7093b1a2db86fa6a.setIcon(icon_3289ae3292a8ccc55cabc3417efa30d4);
#
#
#             var marker_276af0e89074b7787fa28be3d50fdb6d = L.marker(
#                 [31.5882, 74.315],
#                 {
# }
#             ).addTo(map_56188b68cba0caf28915cced3380477c);
#
#
#             var icon_356c6f82b15fea476d2f23065f490568 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkred&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_eb51082060366eb417f98ecd63e177e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa6436437431bd15014abcab92c44828 = $(`&lt;div id=&quot;html_aa6436437431bd15014abcab92c44828&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lahore Fort&lt;/div&gt;`)[0];
#                 popup_eb51082060366eb417f98ecd63e177e3.setContent(html_aa6436437431bd15014abcab92c44828);
#
#
#
#         marker_276af0e89074b7787fa28be3d50fdb6d.bindPopup(popup_eb51082060366eb417f98ecd63e177e3)
#         ;
#
#
#
#
#                 marker_276af0e89074b7787fa28be3d50fdb6d.setIcon(icon_356c6f82b15fea476d2f23065f490568);
#
#
#             var marker_1aaf619c5890a8beae7487c767fae254 = L.marker(
#                 [31.5852, 74.3184],
#                 {
# }
#             ).addTo(map_56188b68cba0caf28915cced3380477c);
#
#
#             var icon_a2187a93cdef5d4aa6903dacb6da2156 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkred&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5bb573183de5a05aa06e99fed2ba3a51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93b80f797a9e9f080039221a61caf2d3 = $(`&lt;div id=&quot;html_93b80f797a9e9f080039221a61caf2d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Data Darbar&lt;/div&gt;`)[0];
#                 popup_5bb573183de5a05aa06e99fed2ba3a51.setContent(html_93b80f797a9e9f080039221a61caf2d3);
#
#
#
#         marker_1aaf619c5890a8beae7487c767fae254.bindPopup(popup_5bb573183de5a05aa06e99fed2ba3a51)
#         ;
#
#
#
#
#                 marker_1aaf619c5890a8beae7487c767fae254.setIcon(icon_a2187a93cdef5d4aa6903dacb6da2156);
#
#
#             var poly_line_7c4b6af4150f555dfb21f357ff7108

# %%
# "Must-visit only" filtered map: places rated 4.5 or higher
top_rated = df[df["avg_rating"] >= 4.5]
print(f"{len(top_rated)} places meet the 4.5+ rating bar:")
print(top_rated[["name", "category", "avg_rating"]].sort_values("avg_rating", ascending=False))

must_visit_map = folium.Map(location=[31.53, 74.34], zoom_start=12)
for row in top_rated.itertuples(index=False):
    color = category_colors.get(row.category, DEFAULT_COLOR)
    folium.Marker(
        [row.lat, row.lon],
        popup=f"{row.name} ({row.avg_rating}★)",
        icon=folium.Icon(color="green" if row.avg_rating >= 4.7 else "orange"),
    ).add_to(must_visit_map)

must_visit_map
# Out:
# 7 places meet the 4.5+ rating bar:
#                  name  category  avg_rating
# 0     Badshahi Mosque  Heritage         4.8
# 1         Lahore Fort  Heritage         4.7
# 16        Data Darbar  Heritage         4.7
# 2   Wazir Khan Mosque  Heritage         4.6
# 4    Minar-e-Pakistan  Heritage         4.6
# 3    Shalimar Gardens  Heritage         4.5
# 10    Gaddafi Stadium    Sports         4.5
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb3586dda09a0da4acaf910029267c89 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb3586dda09a0da4acaf910029267c89&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb3586dda09a0da4acaf910029267c89 = L.map(
#                 &quot;map_cb3586dda09a0da4acaf910029267c89&quot;,
#                 {
#                     center: [31.53, 74.34],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f176322db76c54eb2862d97a97a6eb4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8f176322db76c54eb2862d97a97a6eb4.addTo(map_cb3586dda09a0da4acaf910029267c89);
#
#
#             var marker_4155601c3cbd3ddbcc8da3136070a5b2 = L.marker(
#                 [31.5881, 74.3103],
#                 {
# }
#             ).addTo(map_cb3586dda09a0da4acaf910029267c89);
#
#
#             var icon_7b12f462e2f0b8a48f1cdd1808de4b00 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_128a78211378545f4e7126e5b0a3740d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cf87f5e72802855961cdc6371d2f5c9 = $(`&lt;div id=&quot;html_6cf87f5e72802855961cdc6371d2f5c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Badshahi Mosque (4.8★)&lt;/div&gt;`)[0];
#                 popup_128a78211378545f4e7126e5b0a3740d.setContent(html_6cf87f5e72802855961cdc6371d2f5c9);
#
#
#
#         marker_4155601c3cbd3ddbcc8da3136070a5b2.bindPopup(popup_128a78211378545f4e7126e5b0a3740d)
#         ;
#
#
#
#
#                 marker_4155601c3cbd3ddbcc8da3136070a5b2.setIcon(icon_7b12f462e2f0b8a48f1cdd1808de4b00);
#
#
#             var marker_8ea6b06dcfd1c390fe408c5dfae37c3a = L.marker(
#                 [31.5882, 74.315],
#                 {
# }
#             ).addTo(map_cb3586dda09a0da4acaf910029267c89);
#
#
#             var icon_4a81f0e6e8484f688e5ebedf8aae15ff = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_db1c685925759177addf8ee8e8df29ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2289e71f0622ffd64e97659d087f84d = $(`&lt;div id=&quot;html_b2289e71f0622ffd64e97659d087f84d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lahore Fort (4.7★)&lt;/div&gt;`)[0];
#                 popup_db1c685925759177addf8ee8e8df29ac.setContent(html_b2289e71f0622ffd64e97659d087f84d);
#
#
#
#         marker_8ea6b06dcfd1c390fe408c5dfae37c3a.bindPopup(popup_db1c685925759177addf8ee8e8df29ac)
#         ;
#
#
#
#
#                 marker_8ea6b06dcfd1c390fe408c5dfae37c3a.setIcon(icon_4a81f0e6e8484f688e5ebedf8aae15ff);
#
#
#             var marker_56e4bb2ae4ec52118733c057eb33e5f2 = L.marker(
#                 [31.5828, 74.3323],
#                 {
# }
#             ).addTo(map_cb3586dda09a0da4acaf910029267c89);
#
#
#             var icon_d9b56d6ec961a5174741803d68e11690 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_705bb00d4f07c7821f94ee5338bc5293 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39263674bf3498f434a4c72b35dd0868 = $(`&lt;div id=&quot;html_39263674bf3498f434a4c72b35dd0868&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wazir Khan Mosque (4.6★)&lt;/div&gt;`)[0];
#                 popup_705bb00d4f07c7821f94ee5338bc5293.setContent(html_39263674bf3498f434a4c72b35dd0868);
#
#
#
#         marker_56e4bb2ae4ec52118733c057eb33e5f2.bindPopup(popup_705bb00d4f07c7821f94ee5338bc5293)
#         ;
#
#
#
#
#                 marker_56e4bb2ae4ec52118733c057eb33e5f2.setIcon(icon_d9b56d6ec961a5174741803d68e11690);
#
#
#             var marker_481c87b8e2ed9
