# %%
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
! pip install langchain-classic
! pip install langchain-core
! pip install langchain-openai
! pip install langchain-experimental
! pip install langchain-community
! pip install langchain-text-splitters
! pip install openai
! pip install python-dotenv
! pip install pydantic
! pip install SQLAlchemy
! pip install wikipedia
# Out:
# Requirement already satisfied: langchain-classic in c:\users\mati\anaconda3\lib\site-packages (1.0.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.4 in c:\users\mati\anaconda3\lib\site-packages (from langchain-classic) (1.4.8)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\users\mati\anaconda3\lib\site-packages (from langchain-classic) (1.1.2)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in c:\users\mati\anaconda3\lib\site-packages (from langchain-classic) (0.10.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\mati\anaconda3\lib\site-packages (from langchain-classic) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-classic) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-classic) (2.32.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-classic) (2.0.43)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.4->langchain-classic) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.4->langchain-classic) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.4->langchain-classic) (25.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.4->langchain-classic) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.4->langchain-classic) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.4->langchain-classic) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mati\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.4->langchain-classic) (3.0.0)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (4.10.0)
# Requirement already satisfied: distro>=1.7.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (1.3.0)
# Requirement already satisfied: websockets>=15.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.24.0)
# Requirement already satisfied: certifi in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.9)
# Requirement already satisfied: idna in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\mati\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mati\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mati\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\mati\anaconda3\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-classic) (3.2.4)
# Requirement already satisfied: langchain-core in c:\users\mati\anaconda3\lib\site-packages (1.4.8)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core) (0.10.6)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mati\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (4.10.0)
# Requirement already satisfied: distro>=1.7.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.0)
# Requirement already satisfied: websockets>=15.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.24.0)
# Requirement already satisfied: certifi in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\mati\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mati\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mati\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.5.0)
# Requirement already satisfied: langchain-openai in c:\users\mati\anaconda3\lib\site-packages (1.3.5)
# Collecting langchain-core<2.0.0,>=1.4.9 (from langchain-openai)
#   Using cached langchain_core-1.4.9-py3-none-any.whl.metadata (4.7 kB)
# Collecting openai<3.0.0,>=2.45.0 (from langchain-openai)
#   Using cached openai-2.46.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain-openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain-openai) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain-openai) (0.10.6)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain-openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain-openai) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain-openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mati\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.9->langchain-openai) (3.0.0)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (4.10.0)
# Requirement already satisfied: distro>=1.7.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (1.3.0)
# Requirement already satisfied: websockets>=15.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (0.24.0)
# Requirement already satisfied: certifi in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\mati\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (0.16.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\mati\anaconda3\lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (0.12.0)
# Requirement already satisfied: tqdm>4 in c:\users\mati\anaconda3\lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.9->langchain-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.9->langchain-openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.9->langchain-openai) (0.4.2)
# Requirement already satisfied: regex in c:\users\mati\anaconda3\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mati\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mati\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain-openai) (2.5.0)
# Requirement already satisfied: colorama in c:\users\mati\anaconda3\lib\site-packages (from tqdm>4->openai<3.0.0,>=2.45.0->langchain-openai) (0.4.6)
# Using cached langchain_core-1.4.9-py3-none-any.whl (558 kB)
# Using cached openai-2.46.0-py3-none-any.whl (1.6 MB)
# Installing collected packages: openai, langchain-core
#
#   Attempting uninstall: openai
#
#     Found existing installation: openai 2.30.0
#
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#     Uninstalling openai-2.30.0:
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#       Successfully uninstalled openai-2.30.0
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#    ---------------------------------------- 0/2 [openai]
#   Attempting uninstall: langchain-core
#    ---------------------------------------- 0/2 [openai]
#     Found existing installation: langchain-core 1.4.8
#    ---------------------------------------- 0/2 [openai]
#     Uninstalling langchain-core-1.4.8:
#    ---------------------------------------- 0/2 [openai]
#       Successfully uninstalled langchain-core-1.4.8
#    ---------------------------------------- 0/2 [openai]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
#    ---------------------------------------- 2/2 [langchain-core]
#
# Successfully installed langchain-core-1.4.9 openai-2.46.0
# Requirement already satisfied: langchain-experimental in c:\users\mati\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-experimental) (1.4.9)
# Requirement already satisfied: langchain-community<1.0.0,>=0.4.2 in c:\users\mati\anaconda3\lib\site-packages (from langchain-experimental) (0.4.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (3.13.2)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (1.0.8)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (0.10.6)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (2.3.5)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (2.12.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (2.32.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (2.0.43)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community<1.0.0,>=0.4.2->langchain-experimental) (9.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\mati\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\mati\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mati\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mati\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mati\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\mati\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\mati\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (1.22.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\users\mati\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\mati\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-experimental) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-experimental) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-experimental) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-experimental) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-experimental) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mati\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-experimental) (3.0.0)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (4.10.0)
# Requirement already satisfied: distro>=1.7.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (1.3.0)
# Requirement already satisfied: websockets>=15.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (0.24.0)
# Requirement already satisfied: certifi in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (1.0.9)
# Requirement already satisfied: idna in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\mati\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\mati\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mati\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mati\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\mati\anaconda3\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community<1.0.0,>=0.4.2->langchain-experimental) (3.2.4)
# Requirement already satisfied: langchain-community in c:\users\mati\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community) (1.4.9)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community) (0.10.6)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community) (2.3.5)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community) (2.0.43)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\mati\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\mati\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mati\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mati\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mati\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\mati\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\mati\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\users\mati\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\mati\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mati\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.0.0)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.10.0)
# Requirement already satisfied: distro>=1.7.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: websockets>=15.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.24.0)
# Requirement already satisfied: certifi in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\mati\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\mati\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mati\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mati\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\mati\anaconda3\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: langchain-text-splitters in c:\users\mati\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in c:\users\mati\anaconda3\lib\site-packages (from langchain-text-splitters) (1.4.9)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.10.6)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\mati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mati\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.10.0)
# Requirement already satisfied: distro>=1.7.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.3.0)
# Requirement already satisfied: websockets>=15.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\mati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.24.0)
# Requirement already satisfied: certifi in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\mati\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mati\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mati\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.5.0)
# Requirement already satisfied: openai in c:\users\mati\anaconda3\lib\site-packages (2.46.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\mati\anaconda3\lib\site-packages (from openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\mati\anaconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mati\anaconda3\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\mati\anaconda3\lib\site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\mati\anaconda3\lib\site-packages (from openai) (2.12.4)
# Requirement already satisfied: sniffio in c:\users\mati\anaconda3\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\mati\anaconda3\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\users\mati\anaconda3\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\mati\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\mati\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\mati\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\mati\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in c:\users\mati\anaconda3\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: python-dotenv in c:\users\mati\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: pydantic in c:\users\mati\anaconda3\lib\site-packages (2.12.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mati\anaconda3\lib\site-packages (from pydantic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\mati\anaconda3\lib\site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\mati\anaconda3\lib\site-packages (from pydantic) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\mati\anaconda3\lib\site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: SQLAlchemy in c:\users\mati\anaconda3\lib\site-packages (2.0.43)
# Requirement already satisfied: greenlet>=1 in c:\users\mati\anaconda3\lib\site-packages (from SQLAlchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\mati\anaconda3\lib\site-packages (from SQLAlchemy) (4.15.0)
# Requirement already satisfied: wikipedia in c:\users\mati\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\mati\anaconda3\lib\site-packages (from wikipedia) (4.13.5)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\mati\anaconda3\lib\site-packages (from wikipedia) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mati\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mati\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mati\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mati\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2026.6.17)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mati\anaconda3\lib\site-packages (from beautifulsoup4->wikipedia) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\mati\anaconda3\lib\site-packages (from beautifulsoup4->wikipedia) (4.15.0)

# %%
import sys
# !{sys.executable} -m pip install --upgrade --force-reinstall uuid_utils
# Out:
# Collecting uuid_utils
#   Using cached uuid_utils-0.17.0-cp313-cp313-win_amd64.whl.metadata (6.5 kB)
# Using cached uuid_utils-0.17.0-cp313-cp313-win_amd64.whl (173 kB)
# Installing collected packages: uuid_utils
#   Attempting uninstall: uuid_utils
#     Found existing installation: uuid_utils 0.12.0
#     Uninstalling uuid_utils-0.12.0:
#       Successfully uninstalled uuid_utils-0.12.0
#   Rolling back uninstall of uuid_utils
#   Moving to c:\users\mati\anaconda3\lib\site-packages\uuid_utils-0.12.0.dist-info\
#    from C:\Users\Mati\anaconda3\Lib\site-packages\~uid_utils-0.12.0.dist-info
#   Moving to c:\users\mati\anaconda3\lib\site-packages\uuid_utils\__init__.py
#    from C:\Users\Mati\AppData\Local\Temp\pip-uninstall-lr315hk8\__init__.py
#   Moving to c:\users\mati\anaconda3\lib\site-packages\uuid_utils\__init__.pyi
#    from C:\Users\Mati\AppData\Local\Temp\pip-uninstall-lr315hk8\__init__.pyi
#   Moving to c:\users\mati\anaconda3\lib\site-packages\uuid_utils\__pycache__\
#    from C:\Users\Mati\anaconda3\Lib\site-packages\uuid_utils\~_pycache__
#   Moving to c:\users\mati\anaconda3\lib\site-packages\uuid_utils\_uuid_utils.pyd
#    from C:\Users\Mati\AppData\Local\Temp\pip-uninstall-lr315hk8\_uuid_utils.pyd
#   Moving to c:\users\mati\anaconda3\lib\site-packages\uuid_utils\compat\
#    from C:\Users\Mati\anaconda3\Lib\site-packages\uuid_utils\~ompat
#   Moving to c:\users\mati\anaconda3\lib\site-packages\uuid_utils\py.typed
#    from C:\Users\Mati\AppData\Local\Temp\pip-uninstall-lr315hk8\py.typed
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\Users\\Mati\\anaconda3\\Lib\\site-packages\\uuid_utils\\_uuid_utils.cp313-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
from langchain.chat_models import ChatOpenAI
llm = ChatOpenAI()
output = llm('explain langchain in one line')
print(output)

# %%
import sys
# !{sys.executable} -m pip install --no-binary :all: --force-reinstall uuid_utils
